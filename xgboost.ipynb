# %%
# Import the data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
import utilities
import importlib
importlib.reload(utilities)
from xgboost import XGBClassifier

# %%
df = pd.read_csv('Resources/Customer-Churn-Records.csv')

# %%
# Initialize LogisticRegression
xgb_model = XGBClassifier(random_state=1)

# %%
scores = utilities.processData(df, xgb_model)
# Out:
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697

# %% [markdown]
# print(scores)

# %%
# Create a a list to store accuracy values
balanced_accuracy = []
accuracy = []

# Create a a list to store the values of k
k = list(range(1, 20))

#for i in k:
xgb_model = XGBClassifier()
scores = utilities.processData(df, xgb_model)
balanced_accuracy.append(scores['balanced_accuracy_score'])
accuracy.append(scores['accuracy_score'])
# Out:
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697
# Accuracy Score: 0.856
# Balanced accuracy Score: 0.7258558691222086
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# auc Score:  0.8536238561889697

# %%
# Establish parameters to test for best accuracy
#BELOW PARAM_GRID WAS FOR LOGISTIC_REGRESSION, NOT FOR XGBOOST
param_grid = {

    'C': [0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

# %%
from sklearn.model_selection import GridSearchCV

scores_gscv = utilities.processData(df, grid_search)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='balanced_accuracy')
print("Best parameters found: ", grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 from sklearn.model_selection import GridSearchCV
# ----> 3 scores_gscv = utilities.processData(df, grid_search)
#       4 grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='balanced_accuracy')
#       5 print("Best parameters found: ", grid_search.best_params_)
#
# NameError: name 'grid_search' is not defined
